# %% [markdown]
# # IE 6600 Homework 3
#
# ### MSDAE
#
# ### Aminu Yiwere
#
# #### Northeastern University

# %% [markdown]
# ### Imports

# %%
import numpy as np

# Generate 40 random data points between 1.6 and 9.0
np.random.seed(42)  # For reproducibility
data = np.random.uniform(1.6, 9.0, 40)

# Sort the data
sorted_data = np.sort(data)

# Calculate Q1 (25th percentile)
Q1 = np.percentile(sorted_data, 25)

# Calculate Q2 (Median or 50th percentile)
Q2 = np.median(sorted_data)

# Calculate Q3 (75th percentile)
Q3 = np.percentile(sorted_data, 75)

# Calculate IQR (Interquartile Range)
IQR = Q3 - Q1

# Calculate lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Determine minimum and maximum (excluding outliers)
min_value = sorted_data[sorted_data >= lower_bound][0]
max_value = sorted_data[sorted_data <= upper_bound][-1]

# Identify any outliers
outliers = sorted_data[(sorted_data < lower_bound) | (sorted_data > upper_bound)]

Q1, Q2, Q3, IQR, min_value, max_value, outliers, sorted_data
print(data)
print(sorted_data)
print(f'Q1: {Q1}, Q2: {Q2}, Q3: {Q3}, IQR: {IQR}, MIN: {min_value}, MAX: {max_value}, OUTLIERS: {outliers}')
# Out:
# [4.37159688 8.63528587 7.01675517 6.03007278 2.75453794 2.75435945
#  2.02981873 8.00970348 6.04825109 6.83973708 1.75232526 8.77733291
#  7.76007554 3.17130942 2.94550476 2.95719337 3.8513926  5.48319759
#  4.79639314 3.75509564 6.12771142 2.63225457 3.7618704  4.31107764
#  4.97491788 7.41030211 3.07758599 5.40533484 5.98386781 1.94373305
#  6.0958319  2.86187852 2.08138179 8.62175298 8.74567704 7.58214038
#  3.85414189 2.32277364 6.6633244  4.85712845]
# [1.75232526 1.94373305 2.02981873 2.08138179 2.32277364 2.63225457
#  2.75435945 2.75453794 2.86187852 2.94550476 2.95719337 3.07758599
#  3.17130942 3.75509564 3.7618704  3.8513926  3.85414189 4.31107764
#  4.37159688 4.79639314 4.85712845 4.97491788 5.40533484 5.48319759
#  5.98386781 6.03007278 6.04825109 6.0958319  6.12771142 6.6633244
#  6.83973708 7.01675517 7.41030211 7.58214038 7.76007554 8.00970348
#  8.62175298 8.63528587 8.74567704 8.77733291]
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime

# %% [markdown]
# ## Important Submission Guidelines
#
# In this homework, all the graphs that you present should have proper x-axis and y-axis labels. All graphs should have a meaningful title giving a gist of what the graph is about. By proper and meaningful, it is also meant that the first letter of axis labels should be capitalized, and there should be no undersacores in the name. The default behavior of plotting libraries is to show column names as axis labels. You can customize the labels and titles on your own. For customization purpose `plt.xlabel()`, `plt.ylabel` and `plt.title` commands should help

# %% [markdown]
# ### Question 1
#
# {accuracy: 2}
#
# Run the following cell that should read [this cars dataset](https://raw.githubusercontent.com/qurat-azim/instructionaldatasets/refs/heads/main/data/cars.csv) and store it in a dataframe named `cars`.

# %%
# LOAD DATA HERE
import certifi

# Set the SSL context to use certifi's CA bundle
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
cars = pd.read_csv('https://raw.githubusercontent.com/qurat-azim/instructionaldatasets/refs/heads/main/data/cars.csv')
cars
# Out:
#                           Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0    chevrolet chevelle malibu              18.0          8         307.0
# 1            buick skylark 320              15.0          8         350.0
# 2           plymouth satellite              18.0          8         318.0
# 3                amc rebel sst              16.0          8         304.0
# 4                  ford torino              17.0          8         302.0
# ..                         ...               ...        ...           ...
# 401            ford mustang gl              27.0          4         140.0
# 402                  vw pickup              44.0          4          97.0
# 403              dodge rampage              32.0          4         135.0
# 404                ford ranger              28.0          4         120.0
# 405                 chevy s-10              31.0          4         119.0
#
#      Horsepower  Weight_in_lbs  Acceleration        Year  Origin
# ...

# %% [markdown]
# Now use the `cars` dataframe to create a scatter plot
# with `Weight_in_lbs` on the x-axis
# and `Horsepower` on the y-axis.
# Color the points by the `Origin` of the cars.

# %%
# YOUR CODE HERE
...
sns.scatterplot(data=cars, x='Weight_in_lbs', y = 'Horsepower', hue='Origin')
plt.title("Horsepower vs. Weight of Cars Colored by Origin")
plt.xlabel('Weight in Lbs')
plt.ylabel('Horsepower')
# Out:
# Text(0, 0.5, 'Horsepower')

# %% [markdown]
# ### Question 2
#
# {accuracy: 2}
#
# Make a bar chart showing count of cars in each cylinder category. What is the most common number of cylinders in this dataset?

# %%
# YOUR CODE HERE
...
cylinder_category = cars.groupby(['Cylinders'])[['Name']].count()
cylinder_category.head()
sns.barplot(data=cylinder_category, x= 'Cylinders', y= 'Name')
plt.title("Count of Cars in Each Cylinder Category")
plt.xlabel('Cylinders')
plt.ylabel('Count of Cars')
print('From the barplot, the most common number of cylinders in the dataset is 4')
# Out:
# From the barplot, the most common number of cylinders in the dataset is 4

# %% [markdown]
# > YOUR ANSWER HERE

# %% [markdown]
# ### Question 3
#
# {accuracy: 2}
#
# Run the following cell to store [the stocks data](https://raw.githubusercontent.com/qurat-azim/instructionaldatasets/refs/heads/main/data/stocks.csv) in a dataframe called `stocks`

# %%
# Load dataset here
# stocks
stocks = pd.read_csv('https://raw.githubusercontent.com/qurat-azim/instructionaldatasets/refs/heads/main/data/stocks.csv')
stocks['date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 560 entries, 0 to 559
# Series name: date
# Non-Null Count  Dtype
# --------------  -----
# 560 non-null    object
# dtypes: object(1)
# memory usage: 4.5+ KB

# %% [markdown]
# Let’s use a line plot to visualize how the price of a few common stocks has changed over time.
# Create a line plot with the stocks’ date on the x-axis
# and their price on the y-axis.
# You should colour the lines by the stock symbol
# so that you can compare the stock development for the different companies. Note that the stock's date is already in `datetime` format and you do not have to change it.

# %%
# YOUR CODE HERE
...
import matplotlib.dates as mdates
# Although there is a note that says that the stock's date is already a datetime format, 
# The dates where showing dates from 1970 until i explicitly converted it into a datetime format. 
stocks['date'] = pd.to_datetime(stocks['date'])

plt.figure(figsize=(10, 6))
sns.lineplot(data=stocks, x='date', y='price',hue='symbol')
plt.title('Stock Price Trends Over Time for Selected Companies')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend(title="Stock Symbol")
plt.xticks(rotation=45)

# the dates where cluttered on the x-axis so i had to consult chatgpt for this part of the code
# to format it nicely.
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
# Use AutoDateLocator to automatically determine the best tick positions
plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())

# %% [markdown]
# ### Question 4
#
# {accuracy: 4}
#
# It has been claimed that in the year 2000, IBM stock price was the highest on average. Can you verify this visually using a bar chart? You might have to look up datetime data type comparisons for the data wrangling needed for this task. In your chart, please also put 95% confidence intervals on each bar. Check the documentation [here](https://seaborn.pydata.org/generated/seaborn.barplot.html) for help.
#
# **Note:** If you are using the built-in errorbar fuctionality in seaborn's barplot, you will not need to group the data

# %%
# YOUR CODE HERE
...
stocks_2000 = stocks[stocks['date'].dt.year == 2000]
stocks_2000
plt.figure(figsize=(10, 6))
sns.barplot(data=stocks_2000, x='symbol', y='price', ci=95)
plt.title('Average Stock Price in the Year 2000 with 95% Confidence Intervals')
plt.xlabel('Stock Symbol')
plt.ylabel('Average Price')
plt.show()
# Out:
# /var/folders/z5/2dlc2_2d15qb0wmtpf41r0j00000gn/T/ipykernel_4977/3096899290.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   sns.barplot(data=stocks_2000, x='symbol', y='price', ci=95)

# %% [markdown]
# ### Question 5
#
# {accuracy: 3}
#
# Following on from question 2, make a grouped bar chart for count of cars according to the number of cylinders. This time though, group the bars based on the `Origin`.

# %%
# YOUR CODE HERE
...
sns.countplot(data=cars, x='Cylinders', hue='Origin')
plt.title("Count of Cars in Each Cylinder Category Grouped by Origin")
plt.xlabel('Cylinders')
plt.ylabel('Count of Cars')
plt.legend(title='Origin')
plt.show()

# %% [markdown]
# ### Question 6
#
# {accuracy: 5}
#
# Wrangle the data to make a new column in the cars dataframe called `Fuel_efficiency` with five categories. The categories should follow from values in the `Miles_per_Gallon` column in the following way:
#
# - If `Miles_per_Gallon` is less than 11.0, the `Fuel_efficiency` should be `Very Low`.
# - If `Miles_per_Gallon` is less than 18.0 and greater than or equal to 11.0, the `Fuel_efficiency` should be `Low`.
# - If `Miles_per_Gallon` is less than 25.0 and greater than or equal to 18.0, the `Fuel_efficiency` should be `Average`.
# - If `Miles_per_Gallon` is less than 30.0 and greater than or equal to 25.0, the `Fuel_efficiency` should be `High`.
# - If `Miles_per_Gallon` is greater than or equal to 30.0, the `Fuel_efficiency` should be `Very High`.
#
# Now create a heatmap with `Cylinders` on the x-axis and `Fuel_efficieny` on the y-axis to report `Horsepower`. What general treand do you observe, and how many cylinders would you recommend from the most fuel efficient cars to obtain maximum horsepower.

# %%
# YOUR CODE HERE
...
def categorize_fuel_efficiency(mpg):
    if mpg < 11.0:
        return 'Very Low'
    elif 11.0 <= mpg < 18.0:
        return 'Low'
    elif 18.0 <= mpg < 25.0:
        return 'Average'
    elif 25.0 <= mpg < 30.0:
        return 'High'
    elif mpg >= 30.0:
        return 'Very High'

cars['Fuel_efficiency'] = cars['Miles_per_Gallon'].apply(categorize_fuel_efficiency)

# Create a pivot table for the heatmap
pivot_table = cars.pivot_table(values='Horsepower', index='Fuel_efficiency', columns='Cylinders', aggfunc='mean')

# Plot the heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(pivot_table, cmap='coolwarm', cbar_kws={'label': 'Horsepower'})
plt.title('Heatmap of Horsepower by Cylinders and Fuel Efficiency')
plt.xlabel('Cylinders')
plt.ylabel('Fuel Efficiency')
plt.show()

print("""
To obtain maximum horsepower while maintaining the most fuel-efficient cars, it is recommended to choose cars with 4 or 6 cylinders. 
      These cars strike a balance between fuel efficiency and horsepower, providing a good compromise for performance and economy.
""")
# Out:
# To obtain maximum horsepower while maintaining the most fuel-efficient cars, it is recommended to choose cars with 4 or 6 cylinders.
#       These cars strike a balance between fuel efficiency and horsepower, providing a good compromise for performance and economy.

# %% [markdown]
# > YOUR ANSWER HERE

# %% [markdown]
# ### Question 7
#
# {accuracy: 8, reasoning: 2}
#
# Read and load the data from [this link](https://raw.githubusercontent.com/qurat-azim/instructionaldatasets/main/data/YVR_weather_data.csv). Analyze the data, and see what kind of data you have. Think of three different visuals that provide meaningful analysis of the data. Your task for this exercise is to make one chart with three visual panels in a row. All three panels should present three different kinds of graphs that are insightful. To wind up this task, discuss your insights from the three charts that you present. Remember to be insightful with novel thoughts for this question.

# %%
# YOUR CODE HERE
...
data = pd.read_csv("https://raw.githubusercontent.com/qurat-azim/instructionaldatasets/main/data/YVR_weather_data.csv")
data.head()
# Display basic information about the data
data.info()

# Display summary statistics
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 917 entries, 0 to 916
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date/Time                   917 non-null    object
#  1   Year                        917 non-null    int64
#  2   Month                       917 non-null    int64
#  3   Mean Max Temp (°C)          917 non-null    float64
#  4   Mean Max Temp Flag          6 non-null      object
#  5   Mean Min Temp (°C)          917 non-null    float64
#  6   Mean Min Temp Flag          6 non-null      object
#  7   Mean Temp (°C)              917 non-null    float64
#  8   Mean Temp Flag              6 non-null      object
#  9   Extr Max Temp (°C)          917 non-null    float64
#  10  Extr Max Temp Flag          98 non-null     object
#  11  Extr Min Temp (°C)          917 non-null    float64
#  12  Extr Min Temp Flag          158 non-null    object
# ...

# %%
import matplotlib.pyplot as plt

# Create a figure with three subplots in a row
fig, axs = plt.subplots(1, 3, figsize=(18, 5))

# Line Chart: Temperature over time
axs[0].plot(data['Year'], data['Mean Temp (°C)'], color='blue')
axs[0].set_title('Temperature Over Time')
axs[0].set_xlabel('Date')
axs[0].set_ylabel('Temperature (°C)')

# Histogram: Distribution of Precipitation
axs[1].hist(data['Total Precip (mm)'], bins=10, color='orange')
axs[1].set_title('Distribution of Precipitation')
axs[1].set_xlabel('Precipitation (mm)')
axs[1].set_ylabel('Frequency')

axs[2].plot(data['Year'], data['Mean Max Temp (°C)'], color='red')
axs[2].set_title('Maximum Temperature Over Time')
axs[2].set_xlabel('Date')
axs[2].set_ylabel('Max Temperature (°C)')

# Display the plots
plt.tight_layout()
plt.show()
print("""
Temperature Over Time: The line chart shows the trend of temperature over time. 
We can observe seasonal variations, with higher temperatures in the summer months and lower temperatures in the winter months. 
This helps us understand the overall climate pattern in the region.

Distribution of Precipitation: The histogram shows the distribution of precipitation.
We can see that most days have low precipitation, with a few days having higher amounts.
This indicates that heavy rainfall is relatively rare, but it does occur occasionally.
      
Maximum Temperature Over Time: The line chart shows the trend of maximum temperature over time. 
Similar to the first chart, we can observe seasonal variations, with peaks in the summer months.
This helps us understand the extremes of temperature and how they vary throughout the year.
""")
# Out:
# Temperature Over Time: The line chart shows the trend of temperature over time.
# We can observe seasonal variations, with higher temperatures in the summer months and lower temperatures in the winter months.
# This helps us understand the overall climate pattern in the region.
#
# Distribution of Precipitation: The histogram shows the distribution of precipitation.
# We can see that most days have low precipitation, with a few days having higher amounts.
# This indicates that heavy rainfall is relatively rare, but it does occur occasionally.
#
# Maximum Temperature Over Time: The line chart shows the trend of maximum temperature over time.
# Similar to the first chart, we can observe seasonal variations, with peaks in the summer months.
# This helps us understand the extremes of temperature and how they vary throughout the year.

# %% [markdown]
# ### Question 8 (OPTIONAL):
#
# Give yourself a grade (out of 10) for your effort on this homework.
#
# Reflect on the materials covered during this week. Can you think of any potential improvements? If yes, we'd like to hear from you anonymously [here](https://forms.gle/7gAtFD8APkanWwpC7).

# %% [markdown]
# > YOUR ANSER HERE
